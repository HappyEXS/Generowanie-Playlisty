# %% [markdown]
# # Preprocessing
#
# ## Rozkłady znormalizowanych parametrów piosenek

# %%
from data.loadData import load_tracks

load_tracks(True)
# Out:
#                      track_id  popularity               artist_id  explicit  \
# 0      0RNxWy0PC3AyH4ThH3aGK6          55  19eLuQmk9aCobbVDHc6eek         0
# 1      2W889aLIKxULEefrleFBFI          54  1Mxqyy3pSjf8kZZL4QVxS0         0
# 2      4Pnzw1nLOpDNV6MKI5ueIR          55  1Mxqyy3pSjf8kZZL4QVxS0         0
# 3      7GLmfKOe5BfOXk7334DoKt          54  1Mxqyy3pSjf8kZZL4QVxS0         0
# 4      6kD1SNGPkfX9LwaGd1FG92          53  1Mxqyy3pSjf8kZZL4QVxS0         0
# ...                       ...         ...                     ...       ...
# 22407  0LcNMuOiULmxJK3bdHTfDF          65  7gAppWoH7pcYmphCVTXkzs         0
# 22408  1uviKYHZuM4uINK33F7sCt          70  7okSU80WTrn4LXlyXYbX3P         0
# 22409  1fXmDeiCb3ABt5CzkMxp4u          63  2jnIB6XdLvnJUeNTy5A0J2         0
# 22410  27kcZEJvhkb1rzZS9gCpdA          67  7okSU80WTrn4LXlyXYbX3P         0
# 22411  27Y1N4Q4U3EfDU5Ubw8ws2          70  37M5pPGs6V1fchFJSgCguX         0
#
#                                                   params
# ...
